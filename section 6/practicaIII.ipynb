# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df
# Out:
#                            homename  homecontinent               homecountry  \
# 0            Canadian in La La Land  North America  United States of America
# 1            Canadian in La La Land  North America  United States of America
# 2            Canadian in La La Land  North America  United States of America
# 3            Canadian in La La Land  North America  United States of America
# 4            Canadian in La La Land  North America  United States of America
# ...                             ...            ...                       ...
# 9506  Bridgetown, Western Australia      Australia                 Australia
# 9507                  Lille, France         Europe                    France
# 9508                             MX  South America                    Mexico
# 9509        Kuta - Bali - Indonesia           Asia                 Indonesia
# 9510        Kuta - Bali - Indonesia           Asia                 Indonesia
#
# ...

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

df['homecountry'].unique()
# Out:
# array(['United States of America', 'France', 'Indonesia', 'Spain',
#        'United Kingdom', 'Philippines', 'Australia', 'Germany', 'Brazil',
#        'Ireland', 'Japan', 'Colombia', 'Morocco', 'Chile', 'Kuwait',
#        'Uruguay', 'Italy', 'South Korea', 'Venezuela', 'India', 'Peru',
#        'New Zealand', 'Mexico', 'Oman', 'Netherlands', 'Bangladesh',
#        'Kenya', 'Thailand', 'Switzerland', 'Argentina', 'Lebanon',
#        'Malaysia', 'Poland', 'Dominican Republic', 'Portugal', 'Jordan',
#        'Canada', 'Singapore', 'Costa Rica', 'United Arab Emirates',
#        'Uzbekistan', 'Qatar', 'Panama', 'Saint Barthelemy',
#        'South Africa', 'Ukraine', 'Greece', 'Norway', 'Turkey',
#        'French Polynesia', 'Slovenia', 'Guatemala', 'Taiwan', 'Nicaragua',
#        'Ecuador', 'Hong Kong S.A.R.', 'El Salvador', 'Paraguay', 'Russia',
#        'Namibia', 'Puerto Rico', 'Belgium', 'Nigeria', 'Jersey', 'Cuba',
# ...

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df['homecountry'].unique())
# Out:
# 101

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df['homecountry'].unique())

grouped = df.groupby('homecountry').agg({
    'homename': 'count'
})

grouped
# Out:
#                               homename
# homecountry
# Andorra                              1
# Argentina                          143
# Australia                          809
# Austria                              3
# Bahrain                              2
# ...                                ...
# United States Virgin Islands         2
# United States of America          2826
# Uruguay                             21
# Uzbekistan                           1
# Venezuela                           34
#
# [101 rows x 1 columns]

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df['homecountry'].unique())

grouped = df.groupby('homecountry').agg({
    'homename': 'count'
})

sort_grouped = grouped.sort_values('homename', ascending=False)
top_4 = sort_grouped.head(4)
top_4
# Out:
#                           homename
# homecountry
# United States of America      2826
# Japan                          893
# Australia                      809
# Spain                          752

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df['homecountry'].unique())

grouped = df.groupby('homecountry').agg({
    'homename': 'count'
})

sort_grouped = grouped.sort_values('homename', ascending=False)
top_4 = sort_grouped.head(4)
top_4

df_otros = sort_grouped.drop(index=top_4.index.values) # type: ignore
df_otros
# Out:
#                 homename
# homecountry
# United Kingdom       496
# France               433
# Brazil               379
# Portugal             367
# Italy                295
# ...                  ...
# Nepal                  1
# Oman                   1
# Pakistan               1
# Paraguay               1
# Andorra                1
#
# [97 rows x 1 columns]

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df['homecountry'].unique())

grouped = df.groupby('homecountry').agg({
    'homename': 'count'
})

sort_grouped = grouped.sort_values('homename', ascending=False)
top_4 = sort_grouped.head(4)
top_4

df_otros = sort_grouped.drop(index=top_4.index.values) # type: ignore
df_otros

df_otros['pais'] = 'Otros'
df_otros
# Out:
#                 homename   pais
# homecountry
# United Kingdom       496  Otros
# France               433  Otros
# Brazil               379  Otros
# Portugal             367  Otros
# Italy                295  Otros
# ...                  ...    ...
# Nepal                  1  Otros
# Oman                   1  Otros
# Pakistan               1  Otros
# Paraguay               1  Otros
# Andorra                1  Otros
#
# [97 rows x 2 columns]

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df['homecountry'].unique())

grouped = df.groupby('homecountry').agg({
    'homename': 'count'
})

sort_grouped = grouped.sort_values('homename', ascending=False)
top_4 = sort_grouped.head(4)
top_4

df_otros = sort_grouped.drop(index=top_4.index.values) # type: ignore
df_otros['pais'] = 'Otros'
df_otros

df_otros.groupby('pais').agg({
    'homename': 'sum'
})
# Out:
#        homename
# pais
# Otros      4231

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df["homecountry"].unique())

grouped = df.groupby("homecountry").agg({"homename": "count"})

sort_grouped = grouped.sort_values("homename", ascending=False)
top_4 = sort_grouped.head(4)


df_otros = sort_grouped.drop(index=top_4.index.values)  # type: ignore
df_otros["país"] = "Otros"
df_otros

df_otros_grouped = df_otros.groupby("país").agg({"homename": "sum"})
df_otros_grouped = df_otros_grouped.reset_index()
df_otros_grouped
top_4 = top_4.reset_index()
top_4.columns = ["país", "homename"]
top_4

# df_total = top_4.merge(df_otros_grouped, on="país", how="left")
# Out:
#                        país  homename
# 0  United States of America      2826
# 1                     Japan       893
# 2                 Australia       809
# 3                     Spain       752

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df["homecountry"].unique())

grouped = df.groupby("homecountry").agg({"homename": "count"})

sort_grouped = grouped.sort_values("homename", ascending=False)
top_4 = sort_grouped.head(4)


df_otros: pd.DataFrame = sort_grouped.drop(index=top_4.index.values)  # type: ignore
df_otros["país"] = "Otros"
df_otros

df_otros_grouped: pd.DataFrame = df_otros.groupby("país").agg({"homename": "sum"})
df_otros_grouped = df_otros_grouped.reset_index()
df_otros_grouped
top_4 = top_4.reset_index()
top_4.columns = ["país", "homename"]
top_4

df_total = pd.concat([top_4, df_otros_grouped])

df_total
# Out:
#                        país  homename
# 0  United States of America      2826
# 1                     Japan       893
# 2                 Australia       809
# 3                     Spain       752
# 0                     Otros      4231

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df["homecountry"].unique())

grouped = df.groupby("homecountry").agg({"homename": "count"})

sort_grouped = grouped.sort_values("homename", ascending=False)
top_4 = sort_grouped.head(4)


df_otros: pd.DataFrame = sort_grouped.drop(index=top_4.index.values)  # type: ignore
df_otros["país"] = "Otros"
df_otros

df_otros_grouped: pd.DataFrame = df_otros.groupby("país").agg({"homename": "sum"})
df_otros_grouped = df_otros_grouped.reset_index()
df_otros_grouped
top_4 = top_4.reset_index()
top_4.columns = ["país", "homename"]
top_4

df_final = pd.concat([top_4, df_otros_grouped])

df_final = df_final.set_index("país")
df_final
# Out:
#                           homename
# país
# United States of America      2826
# Japan                          893
# Australia                      809
# Spain                          752
# Otros                         4231

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df["homecountry"].unique())

grouped = df.groupby("homecountry").agg({"homename": "count"})

sort_grouped = grouped.sort_values("homename", ascending=False)
top_4 = sort_grouped.head(4)


df_otros: pd.DataFrame = sort_grouped.drop(index=top_4.index.values)  # type: ignore
df_otros["país"] = "Otros"
df_otros

df_otros_grouped: pd.DataFrame = df_otros.groupby("país").agg({"homename": "sum"})
df_otros_grouped = df_otros_grouped.reset_index()
df_otros_grouped
top_4 = top_4.reset_index()
top_4.columns = ["país", "homename"]
top_4

df_final = pd.concat([top_4, df_otros_grouped])

df_final = df_final.set_index("país")
df_final.plot.pie(
    y="homename",
    autopct="%1.1f%%",
    startangle=90,
    legend=False,
    title="Porcentaje de surfistas por país",
    figsize=(10, 10),
    fontsize=14,
    explode=(0.1, 0, 0, 0, 0),
    shadow=True,
    colors=["#ff9999", "#66b3ff", "#99ff99", "#ffcc99", "#c2c2f0"],
)
# Out:
# <Axes: title={'center': 'Porcentaje de surfistas por país'}, ylabel='homename'>

# %%
import pandas as pd

df = pd.read_csv("../../../data/viajes_surfistas.csv")
df

len(df["homecountry"].unique())

grouped = df.groupby("homecountry").agg({"homename": "count"})

sort_grouped = grouped.sort_values("homename", ascending=False)
top_4 = sort_grouped.head(4)


df_otros: pd.DataFrame = sort_grouped.drop(index=top_4.index.values)  # type: ignore
df_otros["país"] = "Otros"
df_otros

df_otros_grouped: pd.DataFrame = df_otros.groupby("país").agg({"homename": "sum"})
df_otros_grouped = df_otros_grouped.reset_index()
df_otros_grouped
top_4 = top_4.reset_index()
top_4.columns = ["país", "homename"]
top_4

df_final = pd.concat([top_4, df_otros_grouped])

df_final = df_final.set_index("país")
ax = df_final.plot.pie(
    y="homename",
    autopct="%1.1f%%",
    startangle=90,
    title="Porcentaje de Surfistas por País de Procedencia",
    figsize=(10, 10),
    fontsize=14,
    explode=(0.1, 0, 0, 0, 0),
    shadow=True,
    colors=["#ff9999", "#66b3ff", "#99ff99", "#ffcc99", "#c2c2f0"],
)

ax.set_ylabel('')
ax.legend(
    title="País de surfistas",
    bbox_to_anchor=(0.8, 1),
    loc=2,
    borderaxespad=0.0,
)
