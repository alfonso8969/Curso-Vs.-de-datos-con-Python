# %%
import pandas as pd 


df1 = pd.read_csv("../../../NIVEL0/dataset_2a.csv", index_col="id")
df2 = pd.read_csv("../../../NIVEL0/dataset_2b.csv", index_col="user")
df3 = pd.read_csv("../../../NIVEL0/dataset_2c.csv", index_col="ciudad")

df1
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183733                           Programming is the best!      467.0
# 183734                             I cannot believe this!       50.0
# 183735                             Buy this product NOW!!      418.0
# 183736  I have one is best color gradients: Just relea...      361.0
# 183737                                              PIC!!      346.0
# 183738                             hmmm feeling bad today      296.0
# 183739                          not feeling god right now      315.0
# 183740                        Programming is a hot topic!      133.0
# 183741                            Programming? i love it!       92.0
# 183742                                            WHAT???      255.0
# 183743                         Amazing video by Leonardo!      432.0
# 183744                                        Thanks man!      430.0
# 183745          There is nothing better than programming!      424.0
# 183746                                           BORED AF      488.0
# 183747  I do not know if i like programming or other t...      318.0
#
#         retweets  mentions             user fecha_publicado
# id
# 183721       NaN      10.0    leonardokuffo      27/01/2023
# 183722      21.0       NaN    mateusmartins      27/01/2023
# 183723     123.0       6.0      pedrojuarez      28/01/2023
# 183724      76.0       3.0     galocastillo      28/01/2023
# 183725     130.0       9.0      pedrojuarez      28/01/2023
# 183726      70.0       6.0    mateusmartins      29/01/2023
# 183727      40.0      22.0    leonardokuffo      29/01/2023
# 183728      50.0      10.0      pedrojuarez      29/01/2023
# 183729      82.0      26.0      pedrojuarez      30/01/2023
# 183730      92.0      29.0    mateusmartins      31/01/2023
# 183731     111.0       8.0    mateusmartins      31/01/2023
# 183732      44.0      19.0    mateusmartins      31/01/2023
# 183733      69.0      10.0    leonardokuffo      01/02/2023
# 183734      24.0      22.0    leonardokuffo      01/02/2023
# 183735      24.0       2.0  gabrielcarvajal      01/02/2023
# 183736      92.0       1.0      pedrojuarez      02/02/2023
# 183737     115.0      24.0       lucasperes      03/02/2023
# 183738      93.0      29.0  gabrielcarvajal      04/02/2023
# 183739      26.0      10.0     galocastillo      05/02/2023
# 183740     145.0      15.0       lucasperes      05/02/2023
# 183741     146.0       1.0     galocastillo      05/02/2023
# 183742      73.0      17.0     galocastillo      05/02/2023
# 183743      95.0      18.0       lucasperes      06/02/2023
# 183744     143.0      28.0       lucasperes      07/02/2023
# 183745     110.0      29.0       lucasperes      02/03/2023
# 183746      28.0      27.0  gabrielcarvajal      02/03/2023
# 183747      58.0      20.0  isabelladasilva      03/03/2023

# %%
import pandas as pd 


df1 = pd.read_csv("../../../NIVEL0/dataset_2a.csv", index_col="id")
df2 = pd.read_csv("../../../NIVEL0/dataset_2b.csv", index_col="user")
df3 = pd.read_csv("../../../NIVEL0/dataset_2c.csv", index_col="ciudad")

df1
df2
# Out:
#                          ciudad  followers  followees
# user
# leonardokuffo         GUAYAQUIL      389.0        258
# mateusmartins         SAO PAULO      982.0       1822
# pedrojuarez              OAXACA       12.0        129
# galocastillo              QUITO      332.0        378
# gabrielcarvajal     GUADALAJARA       21.0       2721
# lucasperes       RIO DE JANEIRO       82.0        351
# isabelladasilva    PORTO ALEGRE      928.0       9918

# %%
import pandas as pd


df1 = pd.read_csv("../../../NIVEL0/dataset_2a.csv", index_col="id")
df2 = pd.read_csv("../../../NIVEL0/dataset_2b.csv", index_col="user")
df3 = pd.read_csv("../../../NIVEL0/dataset_2c.csv", index_col="ciudad")

df1
df2
df3
# Out:
#                    pais
# ciudad
# GUAYAQUIL       ECUADOR
# RIO DE JANEIRO   BRASIL
# GUADALAJARA      MEXICO
# OAXACA           MEXICO
# QUITO           ECUADOR
# SAO PAULO        BRASIL
# BELO HORIZONTE   BRASIL

# %%
import pandas as pd


df1 = pd.read_csv("../../../NIVEL0/dataset_2a.csv", index_col="id")
df2 = pd.read_csv("../../../NIVEL0/dataset_2b.csv", index_col="user")
df3 = pd.read_csv("../../../NIVEL0/dataset_2c.csv", index_col="ciudad")

df1
df2
df3

df_usuarios = df1.merge(df2, on="user", how="left")
df_usuarios
# Out:
#                                             full_text  favorites  retweets  \
# 0   Flying home to run down from the power to comi...       23.0       NaN
# 1                 Today we commemorate and MNML Case.      500.0      21.0
# 2        Today we have reached US$6.55 Billion TT$44…      190.0     123.0
# 3   Faking It by Joel Atwell. Written by Other cou...      131.0      76.0
# 4                                     Welcome back! 🙌      113.0     130.0
# 5   Contest: Win a fan of his ass. #thatisall Thanks!      492.0      70.0
# 6                                  80's & friends! ✈️      158.0      40.0
# 7   Thank you guess how did I feel somewhat offend...        NaN      50.0
# 8         OnePlus 8 international giveaway classifies      198.0      82.0
# 9                 Here it is.. Retweet this desperate      272.0      92.0
# 10  Great to advertise during the year I tweeted a...       43.0     111.0
# 11  Its been in love with the game with the origin...      349.0      44.0
# 12                           Programming is the best!      467.0      69.0
# 13                             I cannot believe this!       50.0      24.0
# 14                             Buy this product NOW!!      418.0      24.0
# 15  I have one is best color gradients: Just relea...      361.0      92.0
# 16                                              PIC!!      346.0     115.0
# 17                             hmmm feeling bad today      296.0      93.0
# 18                          not feeling god right now      315.0      26.0
# 19                        Programming is a hot topic!      133.0     145.0
# 20                            Programming? i love it!       92.0     146.0
# 21                                            WHAT???      255.0      73.0
# 22                         Amazing video by Leonardo!      432.0      95.0
# 23                                        Thanks man!      430.0     143.0
# 24          There is nothing better than programming!      424.0     110.0
# 25                                           BORED AF      488.0      28.0
# 26  I do not know if i like programming or other t...      318.0      58.0
#
#     mentions             user fecha_publicado          ciudad  followers  \
# 0       10.0    leonardokuffo      27/01/2023       GUAYAQUIL      389.0
# 1        NaN    mateusmartins      27/01/2023       SAO PAULO      982.0
# 2        6.0      pedrojuarez      28/01/2023          OAXACA       12.0
# 3        3.0     galocastillo      28/01/2023           QUITO      332.0
# 4        9.0      pedrojuarez      28/01/2023          OAXACA       12.0
# 5        6.0    mateusmartins      29/01/2023       SAO PAULO      982.0
# 6       22.0    leonardokuffo      29/01/2023       GUAYAQUIL      389.0
# 7       10.0      pedrojuarez      29/01/2023          OAXACA       12.0
# 8       26.0      pedrojuarez      30/01/2023          OAXACA       12.0
# 9       29.0    mateusmartins      31/01/2023       SAO PAULO      982.0
# 10       8.0    mateusmartins      31/01/2023       SAO PAULO      982.0
# 11      19.0    mateusmartins      31/01/2023       SAO PAULO      982.0
# 12      10.0    leonardokuffo      01/02/2023       GUAYAQUIL      389.0
# 13      22.0    leonardokuffo      01/02/2023       GUAYAQUIL      389.0
# 14       2.0  gabrielcarvajal      01/02/2023     GUADALAJARA       21.0
# 15       1.0      pedrojuarez      02/02/2023          OAXACA       12.0
# 16      24.0       lucasperes      03/02/2023  RIO DE JANEIRO       82.0
# 17      29.0  gabrielcarvajal      04/02/2023     GUADALAJARA       21.0
# 18      10.0     galocastillo      05/02/2023           QUITO      332.0
# 19      15.0       lucasperes      05/02/2023  RIO DE JANEIRO       82.0
# 20       1.0     galocastillo      05/02/2023           QUITO      332.0
# 21      17.0     galocastillo      05/02/2023           QUITO      332.0
# 22      18.0       lucasperes      06/02/2023  RIO DE JANEIRO       82.0
# 23      28.0       lucasperes      07/02/2023  RIO DE JANEIRO       82.0
# 24      29.0       lucasperes      02/03/2023  RIO DE JANEIRO       82.0
# 25      27.0  gabrielcarvajal      02/03/2023     GUADALAJARA       21.0
# 26      20.0  isabelladasilva      03/03/2023    PORTO ALEGRE      928.0
#
#     followees
# 0         258
# 1        1822
# 2         129
# 3         378
# 4         129
# 5        1822
# 6         258
# 7         129
# 8         129
# 9        1822
# 10       1822
# 11       1822
# 12        258
# 13        258
# 14       2721
# 15        129
# 16        351
# 17       2721
# 18        378
# 19        351
# 20        378
# 21        378
# 22        351
# 23        351
# 24        351
# 25       2721
# 26       9918

# %%
import pandas as pd


df1 = pd.read_csv("../../../NIVEL0/dataset_2a.csv", index_col="id")
df2 = pd.read_csv("../../../NIVEL0/dataset_2b.csv", index_col="user")
df3 = pd.read_csv("../../../NIVEL0/dataset_2c.csv", index_col="ciudad")

df1
df2
df3

df_usuarios = df1.merge(df2, on="user", how="left")
df_usuarios

df_complete = df_usuarios.merge(df3, on="ciudad", how="left")
df_complete
# Out:
#                                             full_text  favorites  retweets  \
# 0   Flying home to run down from the power to comi...       23.0       NaN
# 1                 Today we commemorate and MNML Case.      500.0      21.0
# 2        Today we have reached US$6.55 Billion TT$44…      190.0     123.0
# 3   Faking It by Joel Atwell. Written by Other cou...      131.0      76.0
# 4                                     Welcome back! 🙌      113.0     130.0
# 5   Contest: Win a fan of his ass. #thatisall Thanks!      492.0      70.0
# 6                                  80's & friends! ✈️      158.0      40.0
# 7   Thank you guess how did I feel somewhat offend...        NaN      50.0
# 8         OnePlus 8 international giveaway classifies      198.0      82.0
# 9                 Here it is.. Retweet this desperate      272.0      92.0
# 10  Great to advertise during the year I tweeted a...       43.0     111.0
# 11  Its been in love with the game with the origin...      349.0      44.0
# 12                           Programming is the best!      467.0      69.0
# 13                             I cannot believe this!       50.0      24.0
# 14                             Buy this product NOW!!      418.0      24.0
# 15  I have one is best color gradients: Just relea...      361.0      92.0
# 16                                              PIC!!      346.0     115.0
# 17                             hmmm feeling bad today      296.0      93.0
# 18                          not feeling god right now      315.0      26.0
# 19                        Programming is a hot topic!      133.0     145.0
# 20                            Programming? i love it!       92.0     146.0
# 21                                            WHAT???      255.0      73.0
# 22                         Amazing video by Leonardo!      432.0      95.0
# 23                                        Thanks man!      430.0     143.0
# 24          There is nothing better than programming!      424.0     110.0
# 25                                           BORED AF      488.0      28.0
# 26  I do not know if i like programming or other t...      318.0      58.0
#
#     mentions             user fecha_publicado          ciudad  followers  \
# 0       10.0    leonardokuffo      27/01/2023       GUAYAQUIL      389.0
# 1        NaN    mateusmartins      27/01/2023       SAO PAULO      982.0
# 2        6.0      pedrojuarez      28/01/2023          OAXACA       12.0
# 3        3.0     galocastillo      28/01/2023           QUITO      332.0
# 4        9.0      pedrojuarez      28/01/2023          OAXACA       12.0
# 5        6.0    mateusmartins      29/01/2023       SAO PAULO      982.0
# 6       22.0    leonardokuffo      29/01/2023       GUAYAQUIL      389.0
# 7       10.0      pedrojuarez      29/01/2023          OAXACA       12.0
# 8       26.0      pedrojuarez      30/01/2023          OAXACA       12.0
# 9       29.0    mateusmartins      31/01/2023       SAO PAULO      982.0
# 10       8.0    mateusmartins      31/01/2023       SAO PAULO      982.0
# 11      19.0    mateusmartins      31/01/2023       SAO PAULO      982.0
# 12      10.0    leonardokuffo      01/02/2023       GUAYAQUIL      389.0
# 13      22.0    leonardokuffo      01/02/2023       GUAYAQUIL      389.0
# 14       2.0  gabrielcarvajal      01/02/2023     GUADALAJARA       21.0
# 15       1.0      pedrojuarez      02/02/2023          OAXACA       12.0
# 16      24.0       lucasperes      03/02/2023  RIO DE JANEIRO       82.0
# 17      29.0  gabrielcarvajal      04/02/2023     GUADALAJARA       21.0
# 18      10.0     galocastillo      05/02/2023           QUITO      332.0
# 19      15.0       lucasperes      05/02/2023  RIO DE JANEIRO       82.0
# 20       1.0     galocastillo      05/02/2023           QUITO      332.0
# 21      17.0     galocastillo      05/02/2023           QUITO      332.0
# 22      18.0       lucasperes      06/02/2023  RIO DE JANEIRO       82.0
# 23      28.0       lucasperes      07/02/2023  RIO DE JANEIRO       82.0
# 24      29.0       lucasperes      02/03/2023  RIO DE JANEIRO       82.0
# 25      27.0  gabrielcarvajal      02/03/2023     GUADALAJARA       21.0
# 26      20.0  isabelladasilva      03/03/2023    PORTO ALEGRE      928.0
#
#     followees     pais
# 0         258  ECUADOR
# 1        1822   BRASIL
# 2         129   MEXICO
# 3         378  ECUADOR
# 4         129   MEXICO
# 5        1822   BRASIL
# 6         258  ECUADOR
# 7         129   MEXICO
# 8         129   MEXICO
# 9        1822   BRASIL
# 10       1822   BRASIL
# 11       1822   BRASIL
# 12        258  ECUADOR
# 13        258  ECUADOR
# 14       2721   MEXICO
# 15        129   MEXICO
# 16        351   BRASIL
# 17       2721   MEXICO
# 18        378  ECUADOR
# 19        351   BRASIL
# 20        378  ECUADOR
# 21        378  ECUADOR
# 22        351   BRASIL
# 23        351   BRASIL
# 24        351   BRASIL
# 25       2721   MEXICO
# 26       9918      NaN

# %%
import pandas as pd


df1 = pd.read_csv("../../../NIVEL0/dataset_2a.csv", index_col="id")
df2 = pd.read_csv("../../../NIVEL0/dataset_2b.csv", index_col="user")
df3 = pd.read_csv("../../../NIVEL0/dataset_2c.csv", index_col="ciudad")

df1
df2
df3

df_usuarios = df1.merge(df2, on="user", how="left")
df_usuarios

df_complete = df_usuarios.merge(df3, on="ciudad", how="left")
df_complete

df_complete['fecha'] = pd.to_datetime(df_complete['fecha_publicado'], format="%d/%m/%Y")
df_complete
# Out:
#                                             full_text  favorites  retweets  \
# 0   Flying home to run down from the power to comi...       23.0       NaN
# 1                 Today we commemorate and MNML Case.      500.0      21.0
# 2        Today we have reached US$6.55 Billion TT$44…      190.0     123.0
# 3   Faking It by Joel Atwell. Written by Other cou...      131.0      76.0
# 4                                     Welcome back! 🙌      113.0     130.0
# 5   Contest: Win a fan of his ass. #thatisall Thanks!      492.0      70.0
# 6                                  80's & friends! ✈️      158.0      40.0
# 7   Thank you guess how did I feel somewhat offend...        NaN      50.0
# 8         OnePlus 8 international giveaway classifies      198.0      82.0
# 9                 Here it is.. Retweet this desperate      272.0      92.0
# 10  Great to advertise during the year I tweeted a...       43.0     111.0
# 11  Its been in love with the game with the origin...      349.0      44.0
# 12                           Programming is the best!      467.0      69.0
# 13                             I cannot believe this!       50.0      24.0
# 14                             Buy this product NOW!!      418.0      24.0
# 15  I have one is best color gradients: Just relea...      361.0      92.0
# 16                                              PIC!!      346.0     115.0
# 17                             hmmm feeling bad today      296.0      93.0
# 18                          not feeling god right now      315.0      26.0
# 19                        Programming is a hot topic!      133.0     145.0
# 20                            Programming? i love it!       92.0     146.0
# 21                                            WHAT???      255.0      73.0
# 22                         Amazing video by Leonardo!      432.0      95.0
# 23                                        Thanks man!      430.0     143.0
# 24          There is nothing better than programming!      424.0     110.0
# 25                                           BORED AF      488.0      28.0
# 26  I do not know if i like programming or other t...      318.0      58.0
#
#     mentions             user fecha_publicado          ciudad  followers  \
# 0       10.0    leonardokuffo      27/01/2023       GUAYAQUIL      389.0
# 1        NaN    mateusmartins      27/01/2023       SAO PAULO      982.0
# 2        6.0      pedrojuarez      28/01/2023          OAXACA       12.0
# 3        3.0     galocastillo      28/01/2023           QUITO      332.0
# 4        9.0      pedrojuarez      28/01/2023          OAXACA       12.0
# 5        6.0    mateusmartins      29/01/2023       SAO PAULO      982.0
# 6       22.0    leonardokuffo      29/01/2023       GUAYAQUIL      389.0
# 7       10.0      pedrojuarez      29/01/2023          OAXACA       12.0
# 8       26.0      pedrojuarez      30/01/2023          OAXACA       12.0
# 9       29.0    mateusmartins      31/01/2023       SAO PAULO      982.0
# 10       8.0    mateusmartins      31/01/2023       SAO PAULO      982.0
# 11      19.0    mateusmartins      31/01/2023       SAO PAULO      982.0
# 12      10.0    leonardokuffo      01/02/2023       GUAYAQUIL      389.0
# 13      22.0    leonardokuffo      01/02/2023       GUAYAQUIL      389.0
# 14       2.0  gabrielcarvajal      01/02/2023     GUADALAJARA       21.0
# 15       1.0      pedrojuarez      02/02/2023          OAXACA       12.0
# 16      24.0       lucasperes      03/02/2023  RIO DE JANEIRO       82.0
# 17      29.0  gabrielcarvajal      04/02/2023     GUADALAJARA       21.0
# 18      10.0     galocastillo      05/02/2023           QUITO      332.0
# 19      15.0       lucasperes      05/02/2023  RIO DE JANEIRO       82.0
# 20       1.0     galocastillo      05/02/2023           QUITO      332.0
# 21      17.0     galocastillo      05/02/2023           QUITO      332.0
# 22      18.0       lucasperes      06/02/2023  RIO DE JANEIRO       82.0
# 23      28.0       lucasperes      07/02/2023  RIO DE JANEIRO       82.0
# 24      29.0       lucasperes      02/03/2023  RIO DE JANEIRO       82.0
# 25      27.0  gabrielcarvajal      02/03/2023     GUADALAJARA       21.0
# 26      20.0  isabelladasilva      03/03/2023    PORTO ALEGRE      928.0
#
#     followees     pais      fecha
# 0         258  ECUADOR 2023-01-27
# 1        1822   BRASIL 2023-01-27
# 2         129   MEXICO 2023-01-28
# 3         378  ECUADOR 2023-01-28
# 4         129   MEXICO 2023-01-28
# 5        1822   BRASIL 2023-01-29
# 6         258  ECUADOR 2023-01-29
# 7         129   MEXICO 2023-01-29
# 8         129   MEXICO 2023-01-30
# 9        1822   BRASIL 2023-01-31
# 10       1822   BRASIL 2023-01-31
# 11       1822   BRASIL 2023-01-31
# 12        258  ECUADOR 2023-02-01
# 13        258  ECUADOR 2023-02-01
# 14       2721   MEXICO 2023-02-01
# 15        129   MEXICO 2023-02-02
# 16        351   BRASIL 2023-02-03
# 17       2721   MEXICO 2023-02-04
# 18        378  ECUADOR 2023-02-05
# 19        351   BRASIL 2023-02-05
# 20        378  ECUADOR 2023-02-05
# 21        378  ECUADOR 2023-02-05
# 22        351   BRASIL 2023-02-06
# 23        351   BRASIL 2023-02-07
# 24        351   BRASIL 2023-03-02
# 25       2721   MEXICO 2023-03-02
# 26       9918      NaN 2023-03-03

# %%
import pandas as pd


df1 = pd.read_csv("../../../NIVEL0/dataset_2a.csv", index_col="id")
df2 = pd.read_csv("../../../NIVEL0/dataset_2b.csv", index_col="user")
df3 = pd.read_csv("../../../NIVEL0/dataset_2c.csv", index_col="ciudad")

df1
df2
df3

df_usuarios = df1.merge(df2, on="user", how="left")
df_usuarios

df_complete = df_usuarios.merge(df3, on="ciudad", how="left")
df_complete

df_complete['fecha'] = pd.to_datetime(df_complete['fecha_publicado'], format="%d/%m/%Y")
df_complete

df_complete['dia_semana'] = df_complete['fecha'].apply(lambda x: x.strftime('%A'))
df_complete
# Out:
#                                             full_text  favorites  retweets  \
# 0   Flying home to run down from the power to comi...       23.0       NaN
# 1                 Today we commemorate and MNML Case.      500.0      21.0
# 2        Today we have reached US$6.55 Billion TT$44…      190.0     123.0
# 3   Faking It by Joel Atwell. Written by Other cou...      131.0      76.0
# 4                                     Welcome back! 🙌      113.0     130.0
# 10       1822   BRASIL 2023-01-31    Tuesday
# 11       1822   BRASIL 2023-01-31    Tuesday
# 12        258  ECUADOR 2023-02-01  Wednesday
# 13        258  ECUADOR 2023-02-01  Wednesday
# 14       2721   MEXICO 2023-02-01  Wednesday
# 15        129   MEXICO 2023-02-02   Thursday
# 16        351   BRASIL 2023-02-03     Friday
# 17       2721   MEXICO 2023-02-04   Saturday
# 18        378  ECUADOR 2023-02-05     Sunday
# 19        351   BRASIL 2023-02-05     Sunday
# 20        378  ECUADOR 2023-02-05     Sunday
# 21        378  ECUADOR 2023-02-05     Sunday
# 22        351   BRASIL 2023-02-06     Monday
# 23        351   BRASIL 2023-02-07    Tuesday
# 24        351   BRASIL 2023-03-02   Thursday
# 25       2721   MEXICO 2023-03-02   Thursday
# 26       9918      NaN 2023-03-03     Friday

# %%
import pandas as pd


df1 = pd.read_csv("../../../NIVEL0/dataset_2a.csv", index_col="id")
df2 = pd.read_csv("../../../NIVEL0/dataset_2b.csv", index_col="user")
df3 = pd.read_csv("../../../NIVEL0/dataset_2c.csv", index_col="ciudad")

df1
df2
df3

df_usuarios = df1.merge(df2, on="user", how="left")
df_usuarios

df_complete = df_usuarios.merge(df3, on="ciudad", how="left")
df_complete

df_complete['fecha'] = pd.to_datetime(df_complete['fecha_publicado'], format="%d/%m/%Y")
df_complete

df_complete['dia_semana'] = df_complete['fecha'].apply(lambda x: x.strftime('%A'))
df_complete

df_complete['mes'] = df_complete['fecha_publicado'].apply(lambda x: x[3:])
df_complete
# Out:
#                                             full_text  favorites  retweets  \
# 0   Flying home to run down from the power to comi...       23.0       NaN
# 1                 Today we commemorate and MNML Case.      500.0      21.0
# 2        Today we have reached US$6.55 Billion TT$44…      190.0     123.0
# 3   Faking It by Joel Atwell. Written by Other cou...      131.0      76.0
# 4                                     Welcome back! 🙌      113.0     130.0
# 5   Contest: Win a fan of his ass. #thatisall Thanks!      492.0      70.0
# 6                                  80's & friends! ✈️      158.0      40.0
# 7   Thank you guess how did I feel somewhat offend...        NaN      50.0
# 8         OnePlus 8 international giveaway classifies      198.0      82.0
# 9                 Here it is.. Retweet this desperate      272.0      92.0
# 10  Great to advertise during the year I tweeted a...       43.0     111.0
# 11  Its been in love with the game with the origin...      349.0      44.0
# 12                           Programming is the best!      467.0      69.0
# 13                             I cannot believe this!       50.0      24.0
# 14                             Buy this product NOW!!      418.0      24.0
# 15  I have one is best color gradients: Just relea...      361.0      92.0
# 16                                              PIC!!      346.0     115.0
# 17                             hmmm feeling bad today      296.0      93.0
# 18                          not feeling god right now      315.0      26.0
# 19                        Programming is a hot topic!      133.0     145.0
# 20                            Programming? i love it!       92.0     146.0
# 21                                            WHAT???      255.0      73.0
# 22                         Amazing video by Leonardo!      432.0      95.0
# 23                                        Thanks man!      430.0     143.0
# 24          There is nothing better than programming!      424.0     110.0
# 25                                           BORED AF      488.0      28.0
# 26  I do not know if i like programming or other t...      318.0      58.0
#
#     mentions             user fecha_publicado          ciudad  followers  \
# 0       10.0    leonardokuffo      27/01/2023       GUAYAQUIL      389.0
# 1        NaN    mateusmartins      27/01/2023       SAO PAULO      982.0
# 2        6.0      pedrojuarez      28/01/2023          OAXACA       12.0
#